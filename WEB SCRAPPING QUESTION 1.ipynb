# %%
! pip install selenium 
from selenium import webdriver
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import re
import requests
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By


import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\abhis\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(6)

# %%
#Creating blank list
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

#Scraping Rank
rank=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
for i in rank:
    Rank.append(i.text)

#Scraping Name
name=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
for i in name:
    Name.append(i.text)
    
#Scraping Artist
artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
for i in artist:
    Artist.append(i.text)
    
    
#Scraping Views
views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
for i in views:
    Views.append(i.text)
    
    
#Scraping Upload_date
upload_date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
for i in upload_date:
    Upload_date.append(i.text)
    
Youtube_viewed=pd.DataFrame({})
Youtube_viewed['Rank']=Rank
Youtube_viewed['Name']=Name
Youtube_viewed['Artist']=Artist
Youtube_viewed['Upload_date']=Upload_date
Youtube_viewed['Views']=Views
Youtube_viewed
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %%
2. Scrape the details team India’s international fixtures from bcci.tv.

# %%
! pip install selenium 
from selenium import webdriver
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import re
import requests
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By


import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\abhis\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(4)

# %%
#click on international


international=driver.find_element(By.XPATH,"/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a")
international.click()


# click on fixtures
fixtures= driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div/ul/li[1]/a")
fixtures.click()

# %%
#Creating Empty list
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

#Scraping Match_title
match_title= driver.find_elements(By.XPATH,"//strong[@class='ng-binding']")
for i in match_title:
    Match_title.append(i.text)
    
#Scraping Series
series= driver.find_elements(By.XPATH,"//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in series:
    Series.append(i.text)
    
#Scraping Place
place= driver.find_elements(By.XPATH,"//p[@class='fixture__additional-info']/span")
for i in place:
    Place.append(i.text)   
    
#Scraping Date
date= driver.find_elements(By.XPATH,"//div[@class='fixture__full-date']")
for i in date:
    Date.append(i.text)   
    
#Scraping Time
time= driver.find_elements(By.XPATH,"//span[@class='fixture__time']")
for i in time:
    Time.append(i.text) 

Fixture=pd.DataFrame({})
Fixture['Match_title']=Match_title
Fixture['Series']=Series
Fixture['Place']=Place
Fixture['Date']=Date
Fixture['Time']=Time
Fixture
# Out:
# Empty DataFrame
# Columns: [Match_title, Series, Place, Date, Time]
# Index: []

# %%
Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
You need to find following details:
A) Name
B) Description
Note: - From guru99 home page you have to reach to selenium exception handling page through code. ,

# %%
driver = webdriver.Chrome(r"C:\Users\abhis\Downloads\chromedriver_win32\chromedriver.exe")
url = "https://www.guru99.com/"
driver.get(url)
driver.maximize_window()

# %%
#clicking on testing 
Testing=driver.find_element(By.XPATH,"//li[@id='menu-item-3173']")
Testing.click()

# clicking on slelenium tutorial 
selenium= driver.find_element(By.XPATH,"//li[@id='menu-item-4622']")
selenium.click()

# Scroling page by elements name
time.sleep(4)
element = driver.find_element(By.XPATH,"//div[@class='entry-content single-content']/table[5]/tbody/tr[34]")
driver.execute_script("return arguments[0].scrollIntoView();", element)

#clicking on Tutotial
Tutotial= driver.find_element(By.XPATH,"//*[@id='post-193']/div/div/table[5]/tbody/tr[34]/td[1]/a")
Tutotial.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [24], in <cell line: 2>()
#       1 # clicking on slelenium tutorial
# ----> 2 selenium= driver.find_element(By.XPATH,"//li[@id='menu-item-147434']")
#       3 selenium.click()
#       5 # Scroling page by elements name
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# ...

# %%
Scrape the details of top 100 songs on billboard.com. Url = https://www.billboard.com/
You have to find the following details:
A) Song name
B) Artist name
C) Last week rank
D) Peak rank
E) Weeks on board
Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
! pip install selenium 
from selenium import webdriver
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import time
import re
import requests
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import WebDriverException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By


import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome(r"C:\Users\abhis\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(4)

url = "https://www.billboard.com/"
driver.get(url)
time.sleep(6)

# %%
time.sleep(3)
Hot_song= driver.find_element(By.XPATH,"//li[@class='header__subnav__item'][3]")
Hot_song.click()
time.sleep(6)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 time.sleep(3)
# ----> 2 Hot_song= driver.find_element(By.XPATH,"//li[@class='header__subnav__item'][3]")
#       3 Hot_song.click()
#       4 time.sleep(6)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
# ...
